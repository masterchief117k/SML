# %%
#kshitij singh rawat  reg:-2241018096
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn import svm

df = pd.read_csv('iris.data')
df.head()
df.columns
df.columns = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']
df.head
df.describe()
y = df['class']
X = df.drop(columns=['class'])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

model = svm.SVC(kernel='linear')

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print(confusion_matrix(y_test, y_pred))
# Out:
# [[19  0  0]
#  [ 0 12  3]
#  [ 0  1 15]]

# %%
#kshitij singh rawat  reg:-2241018096
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn import svm
df = pd.read_csv('iris.data')
df.head()
df.columns
df.columns = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']
df.head
df.describe()
df['class'].value_counts().plot.bar()
y = df['class']
X = df.drop(columns=['class'])
X_train, X_test, y_train, y_test = train_test_split(X, y,
test_size=0.33, random_state=42)
model_svm = svm.SVC(kernel='linear')
model_svm.fit(X_train, y_train)
y_predicted=model_svm.predict(X_test)
print(classification_report(y_test,y_predicted))
print(confusion_matrix(y_test,y_predicted))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       0.92      0.80      0.86        15
#  Iris-virginica       0.83      0.94      0.88        16
#
#        accuracy                           0.92        50
#       macro avg       0.92      0.91      0.91        50
#    weighted avg       0.92      0.92      0.92        50
#
# [[19  0  0]
#  [ 0 12  3]
#  [ 0  1 15]]

# %%
#kshitij singh rawat  reg:-2241018096
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn import svm
df = pd.read_csv('iris.data')
df.head()
df.columns
df.columns = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']
df.head
df.describe()
df['class'].value_counts().plot.bar()
y = df['class']
X = df.drop(columns=['class'])
X_train, X_test, y_train, y_test = train_test_split(X, y,
test_size=0.33, random_state=42)

model_poly = svm.SVC(kernel='poly')

model_poly.fit(X_train, y_train)

y_pred_poly = model_poly.predict(X_test)

print(confusion_matrix(y_test, y_pred_poly))
# Out:
# [[19  0  0]
#  [ 0 12  3]
#  [ 0  1 15]]

# %%
#kshitij singh rawat  reg:-2241018096
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn import svm
df = pd.read_csv('iris.data')
df.head()
df.columns
df.columns = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']
df.head
df.describe()
df['class'].value_counts().plot.bar()
y = df['class']
X = df.drop(columns=['class'])
X_train, X_test, y_train, y_test = train_test_split(X, y,
test_size=0.33, random_state=42)
model_radial = svm.SVC(kernel='rbf')

model_radial.fit(X_train, y_train)

y_pred_radial = model_radial.predict(X_test)

print(confusion_matrix(y_test, y_pred_radial))
# Out:
# [[19  0  0]
#  [ 0 13  2]
#  [ 0  1 15]]

# %%
#kshitij singh rawat  reg:-2241018096

from sklearn.metrics import accuracy_score
accuracy_linear = accuracy_score(y_test, y_pred)
accuracy_poly = accuracy_score(y_test, y_pred_poly)
accuracy_radial = accuracy_score(y_test, y_pred_radial)

print("Accuracy of SVM model with linear kernel: ", accuracy_linear)
print("Accuracy of SVM model with polynomial kernel: ", accuracy_poly)
print("Accuracy of SVM model with radial kernel: ", accuracy_radial)
# Out:
# Accuracy of SVM model with linear kernel:  0.92
# Accuracy of SVM model with polynomial kernel:  0.92
# Accuracy of SVM model with radial kernel:  0.94
